# %% [markdown]
# # Logistic Equation
#
# Galen Wilkerson
#
# More info:
# https://en.wikipedia.org/wiki/Bifurcation_diagram
#
# $$
# \huge f(x) = k x (1 - x)
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
def logistic_equation(k, x):
    return(k * x * (1 - x))

vect_logistic_equation = np.vectorize(logistic_equation)

# %%
def iterate(k, x, num_steps = 100):
    
    for i in range(1, num_steps):
        x = vect_logistic_equation(k, x)
        
    return(x)

vect_iterate = np.vectorize(iterate)

# %%
ks = np.arange(2,4,.0001)
x = .5

ys = vect_iterate(ks, x)

# %%
plt.figure(figsize=[10, 8])
plt.scatter(ks, ys, c='black', marker='o', s=.5);
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %% [markdown]
# Note, it should be possible to use lfilter to vectorize this:
# https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.signal.lfilter.html
